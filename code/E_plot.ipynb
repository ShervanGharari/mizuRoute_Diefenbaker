# %%
# load the packages
import xarray as xr
import pandas as pd
import numpy  as np
from ipynb.fs.full.Untitled2 import save_netcdf
import os
import shutil

# station list
station_list = ["05HG001"] # coresponsing with 16th segment of network topology

# load the file that include the data
ds = xr.open_dataset('/Users/shg096/Desktop/HYDAT_05.nc') # direction to HYDAT_05 point
ds = ds.sel(time=slice('2013-06-01','2013-07-10'))
station_all = list (np.array(ds.Station_ID[:]))

# subseting the netcdf file
idx = [station_all.index(i) for i in station_list]
print(idx)
ds_subset = ds.isel(n=idx)

print(ds_subset)

ds = ds_subset.to_dataframe()

ds = ds.reset_index(level=1, drop=True)

ds = ds['Flow']

ds = pd.DataFrame(ds)

ds = ds.rename(columns={'0':'Flow'})

ds.to_csv('../data/observation_05HG001.csv')
# Out:
# [740]
# <xarray.Dataset>
# Dimensions:          (time: 40, n: 1)
# Coordinates:
#   * time             (time) datetime64[ns] 2013-06-01 2013-06-02 ... 2013-07-10
#     lat              (n) float64 ...
#     lon              (n) float64 ...
#     Station_ID       (n) object ...
# Dimensions without coordinates: n
# Data variables:
#     Flow             (n, time) float64 ...
#     flags            (n, time) |S1 ...
#     DrainageAreaEff  (n) float64 ...
#     DrainageArea     (n) float64 ...
#     Station_Name     (n) object ...
#     ID               (n) int32 ...
# Attributes:
#     Conventions:  CF-1.6
#     License:      The file is created by Shervan Gharari, under MIT, https://...
#     history:      Created Fri Jul 12 22:04:01 2019
#     source:       described 1418 gauges stating with code 05 of WSC HYDAT data

# %%
ds = pd.read_csv('../data/observation_05HG001.csv')

# %%
import numpy as np
import os

path = './ancillary_data/'
file_name_tmp = 'param.nml.default.tmp'
file_name     = 'param.nml.default'

velocities    = np.arange(0.5,1.6,0.1)
diffusivities = np.arange(500,10500,500)
# velocities    = np.arange(0.5,0.7,0.1)
# diffusivities = np.arange(500,1500,500)
old_strings = ["velocity","diffusivity"]

params = None
for velocity in velocities:
    for diffusivity in diffusivities:
        if params is not None:
            params = np.append (params, np.array([[velocity,diffusivity]]),axis=0)
        else:
            params = np.array([[velocity,diffusivity]])

for row in params:
    V = "%.1f" % row[0]
    D = "%.0f" % row[1]
    case_name = 'V_'+V+'_D_'+D
    with open(path+file_name_tmp, "r+") as text_file:
        texts = text_file.read()
        for i in np.arange(len(old_strings)):
            texts = texts.replace(old_strings[i], str(row[i]))
    with open(path+case_name+'_'+file_name, "w") as text_file:
        text_file.write(texts)
        
    # update the case name in the setting file
    with open('./settings/HDMA_CLM5-runoff-lake.control.tmp', "r+") as text_file:
        texts = text_file.read()
        texts = texts.replace("CASENAME", case_name)
    with open('./settings/HDMA_CLM5-runoff-lake.control', "w") as text_file:
        text_file.write(texts)
        
    # execute the model
    os.system('./route_runoff.mpi-pio.exe ./settings/HDMA_CLM5-runoff-lake.control')
# Out:
# [  0.5 500. ]
# 0.5
# 500.0
# V_0.5_D_500.0
# [5.e-01 1.e+03]
# 0.5
# 1000.0
# V_0.5_D_1000.0
# [  0.6 500. ]
# 0.6
# 500.0
# V_0.6_D_500.0
# [6.e-01 1.e+03]
# 0.6
# 1000.0
# V_0.6_D_1000.0

# %%
import xarray as xr
import glob
import pandas as pd
import os

file_names = sorted(glob.glob('./output/test/*.mizuRoute.h.2013-06-01-00000.nc'))

df = pd.DataFrame()

for file_name in file_names:
    ds = xr.open_dataset(file_name)
    base = os.path.basename(file_name)
    base = base.replace('.mizuRoute.h.2013-06-01-00000.nc','')
    print(base)
    df [base] = ds.IRFroutedRunoff[:,15]

df.to_csv('./output/calibration_output.csv')

# %%
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
#import datetime #import date
import matplotlib.pyplot  as plt
import matplotlib
from ipynb.fs.full.Untitled2 import save_netcdf
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 20}
matplotlib.rc('font', **font)

df = pd.read_csv('/Users/shg096/Downloads/calibration_output.csv')

df = df.drop(columns=['Unnamed: 0'])
index = pd.date_range(start='2013-06-01', end='2013-07-10')
df = df.set_index(index)
# df = df.drop(columns=['Unnamed: 0'])

print(df)
print(len(df))
print(len(df.columns))

#
df.plot(figsize=(20,10))
plt.grid(which='both')
plt.gca().get_legend().remove()
plt.ylabel('Discharge at Saskatoon [m3/s]')
# Out:
#             V_0.5_D_1000  V_0.5_D_10000  ...  V_1.5_D_9000  V_1.5_D_9500
# 2013-06-01     238.08992       2.063861  ...     238.10070     225.73802
# 2013-06-02     302.47025       4.785260  ...     302.47860     292.00120
# 2013-06-03     385.46610       5.443431  ...     385.47223     378.00864
# 2013-06-04     423.86798       4.465644  ...     423.87024     420.96204
# 2013-06-05     484.50146       3.203294  ...     484.50333     482.23730
# 2013-06-06     494.53170       2.170658  ...     494.53165     494.57834
# 2013-06-07     503.04446       1.423846  ...     503.04456     503.02454
# 2013-06-08     444.79648       0.914496  ...     444.79560     445.66565
# 2013-06-09     456.07782      24.145990  ...     456.07846     455.38834
# 2013-06-10     476.89005      85.575550  ...     476.89030     476.68167
# 2013-06-11     507.23930     170.876800  ...     507.23972     506.94670
# 2013-06-12     518.14420     258.669000  ...     518.14420     518.21650
# 2013-06-13     466.92093     328.813050  ...     466.91968     468.33456
# 2013-06-14     373.54788     367.264830  ...     373.54572     375.96362
# 2013-06-15     266.72748     372.498050  ...     266.72476     269.78986
# 2013-06-16     331.00443     374.241800  ...     331.00473     331.01224
# 2013-06-17     328.09985     390.543370  ...     328.09796     330.32523
# 2013-06-18     341.48350     417.725070  ...     341.48224     343.11008
# 2013-06-19     420.32727     457.806900  ...     420.32760     420.19897
# 2013-06-20     389.80493     496.106320  ...     389.80356     391.29532
# 2013-06-21     532.87494     532.335500  ...     532.87866     528.91690
# 2013-06-22    1178.32170     613.587950  ...    1178.34290    1155.19410
# 2013-06-23    2789.21440     796.519170  ...    2789.28000    2716.57000
# 2013-06-24    4361.91100    1047.725300  ...    4361.98100    4281.17430
# 2013-06-25    4124.34230    1183.899700  ...    4124.34860    4111.23000
# 2013-06-26    2756.62040    1088.678300  ...    2756.58100    2797.36230
# 2013-06-27    1560.24280     874.783600  ...    1560.20060    1607.58910
# 2013-06-28    1045.87400     751.266700  ...    1045.84850    1076.44760
# 2013-06-29     928.73820     823.477800  ...     928.72460     945.95740
# 2013-06-30    1011.13700    1067.664000  ...    1011.12950    1021.23145
# 2013-07-01     871.65100    1367.566400  ...     871.64100     883.82860
# 2013-07-02     814.42060    1618.290500  ...     814.41580     820.73870
# 2013-07-03     750.47810    1772.735600  ...     750.47450     754.98267
# 2013-07-04     657.90790    1818.680900  ...     657.90436     662.09940
# 2013-07-05     646.66266    1779.318800  ...     646.66090     648.88025
# 2013-07-06     606.98676    1685.163600  ...     606.98460     609.49070
# 2013-07-07     586.23474    1557.721200  ...     586.23390     587.36554
# 2013-07-08     682.41180    1428.273700  ...     682.41350     680.71470
# 2013-07-09     671.49760    1310.046900  ...     671.49640     672.88965
# 2013-07-10     610.40784    1198.093900  ...     610.40520     613.49316
#
# [40 rows x 220 columns]
# 40
# 220
# Text(0, 0.5, 'Discharge at Saskatoon [m3/s]')

# %%
# load the packages
import xarray as xr
import pandas as pd
import numpy  as np
from ipynb.fs.full.Untitled2 import save_netcdf
import os
import shutil

# station list
station_list = ["05HG001"] # coresponsing with 16th segment of network topology

# load the file that include the data
ds = xr.open_dataset('/Users/shg096/Desktop/HYDAT_05.nc') # direction to HYDAT_05 point
ds = ds.sel(time=slice('2013-06-01','2013-07-10'))
station_all = list (np.array(ds.Station_ID[:]))

# subseting the netcdf file
idx = [station_all.index(i) for i in station_list]
print(idx)
ds_subset = ds.isel(n=idx)

print (ds_subset)

observation = np.array(ds_subset.Flow[:]).flatten()

print(observation)
# Out:
# [740]
# <xarray.Dataset>
# Dimensions:          (time: 40, n: 1)
# Coordinates:
#   * time             (time) datetime64[ns] 2013-06-01 2013-06-02 ... 2013-07-10
#     lat              (n) float64 ...
#     lon              (n) float64 ...
#     Station_ID       (n) object ...
# Dimensions without coordinates: n
# Data variables:
#     Flow             (n, time) float64 ...
#     flags            (n, time) |S1 ...
#     DrainageAreaEff  (n) float64 ...
#     DrainageArea     (n) float64 ...
#     Station_Name     (n) object ...
#     ID               (n) int32 ...
# Attributes:
#     Conventions:  CF-1.6
#     License:      The file is created by Shervan Gharari, under MIT, https://...
#     history:      Created Fri Jul 12 22:04:01 2019
#     source:       described 1418 gauges stating with code 05 of WSC HYDAT data
# [ 356.  351.  323.  331.  382.  396.  405.  420.  424.  441.  440.  441.
#   449.  458.  434.  370.  339.  360.  415.  423.  526.  833. 1420. 1960.
#  2120. 2210. 2240. 2200. 2010. 1710. 1510. 1120. 1010.  748.  727.  722.
#   724.  713.  710.  693.]

# %%
# create the observation maximume
df_observed = df.copy()

for column in df_observed.columns:
    df_observed[column] = observation
    
print(df_observed)
print(df)
# Out:
#             V_0.5_D_1000  V_0.5_D_10000  ...  V_1.5_D_9000  V_1.5_D_9500
# 2013-06-01         356.0          356.0  ...         356.0         356.0
# 2013-06-02         351.0          351.0  ...         351.0         351.0
# 2013-06-03         323.0          323.0  ...         323.0         323.0
# 2013-06-04         331.0          331.0  ...         331.0         331.0
# 2013-06-05         382.0          382.0  ...         382.0         382.0
# 2013-06-06         396.0          396.0  ...         396.0         396.0
# 2013-06-07         405.0          405.0  ...         405.0         405.0
# 2013-06-08         420.0          420.0  ...         420.0         420.0
# 2013-06-09         424.0          424.0  ...         424.0         424.0
# 2013-06-10         441.0          441.0  ...         441.0         441.0
# 2013-06-11         440.0          440.0  ...         440.0         440.0
# 2013-06-12         441.0          441.0  ...         441.0         441.0
# 2013-06-13         449.0          449.0  ...         449.0         449.0
# 2013-06-14         458.0          458.0  ...         458.0         458.0
# 2013-06-15         434.0          434.0  ...         434.0         434.0
# 2013-06-16         370.0          370.0  ...         370.0         370.0
# 2013-06-17         339.0          339.0  ...         339.0         339.0
# 2013-06-18         360.0          360.0  ...         360.0         360.0
# 2013-06-19         415.0          415.0  ...         415.0         415.0
# 2013-06-20         423.0          423.0  ...         423.0         423.0
# 2013-06-21         526.0          526.0  ...         526.0         526.0
# 2013-06-22         833.0          833.0  ...         833.0         833.0
# 2013-06-23        1420.0         1420.0  ...        1420.0        1420.0
# 2013-06-24        1960.0         1960.0  ...        1960.0        1960.0
# 2013-06-25        2120.0         2120.0  ...        2120.0        2120.0
# 2013-06-26        2210.0         2210.0  ...        2210.0        2210.0
# 2013-06-27        2240.0         2240.0  ...        2240.0        2240.0
# 2013-06-28        2200.0         2200.0  ...        2200.0        2200.0
# 2013-06-29        2010.0         2010.0  ...        2010.0        2010.0
# 2013-06-30        1710.0         1710.0  ...        1710.0        1710.0
# 2013-07-01        1510.0         1510.0  ...        1510.0        1510.0
# 2013-07-02        1120.0         1120.0  ...        1120.0        1120.0
# 2013-07-03        1010.0         1010.0  ...        1010.0        1010.0
# 2013-07-04         748.0          748.0  ...         748.0         748.0
# 2013-07-05         727.0          727.0  ...         727.0         727.0
# 2013-07-06         722.0          722.0  ...         722.0         722.0
# 2013-07-07         724.0          724.0  ...         724.0         724.0
# 2013-07-08         713.0          713.0  ...         713.0         713.0
# 2013-07-09         710.0          710.0  ...         710.0         710.0
# 2013-07-10         693.0          693.0  ...         693.0         693.0
#
# [40 rows x 220 columns]
#             V_0.5_D_1000  V_0.5_D_10000  ...  V_1.5_D_9000  V_1.5_D_9500
# 2013-06-01     238.08992       2.063861  ...     238.10070     225.73802
# 2013-06-02     302.47025       4.785260  ...     302.47860     292.00120
# 2013-06-03     385.46610       5.443431  ...     385.47223     378.00864
# 2013-06-04     423.86798       4.465644  ...     423.87024     420.96204
# 2013-06-05     484.50146       3.203294  ...     484.50333     482.23730
# 2013-06-06     494.53170       2.170658  ...     494.53165     494.57834
# 2013-06-07     503.04446       1.423846  ...     503.04456     503.02454
# 2013-06-08     444.79648       0.914496  ...     444.79560     445.66565
# 2013-06-09     456.07782      24.145990  ...     456.07846     455.38834
# 2013-06-10     476.89005      85.575550  ...     476.89030     476.68167
# 2013-06-11     507.23930     170.876800  ...     507.23972     506.94670
# 2013-06-12     518.14420     258.669000  ...     518.14420     518.21650
# 2013-06-13     466.92093     328.813050  ...     466.91968     468.33456
# 2013-06-14     373.54788     367.264830  ...     373.54572     375.96362
# 2013-06-15     266.72748     372.498050  ...     266.72476     269.78986
# 2013-06-16     331.00443     374.241800  ...     331.00473     331.01224
# 2013-06-17     328.09985     390.543370  ...     328.09796     330.32523
# 2013-06-18     341.48350     417.725070  ...     341.48224     343.11008
# 2013-06-19     420.32727     457.806900  ...     420.32760     420.19897
# 2013-06-20     389.80493     496.106320  ...     389.80356     391.29532
# 2013-06-21     532.87494     532.335500  ...     532.87866     528.91690
# 2013-06-22    1178.32170     613.587950  ...    1178.34290    1155.19410
# 2013-06-23    2789.21440     796.519170  ...    2789.28000    2716.57000
# 2013-06-24    4361.91100    1047.725300  ...    4361.98100    4281.17430
# 2013-06-25    4124.34230    1183.899700  ...    4124.34860    4111.23000
# 2013-06-26    2756.62040    1088.678300  ...    2756.58100    2797.36230
# 2013-06-27    1560.24280     874.783600  ...    1560.20060    1607.58910
# 2013-06-28    1045.87400     751.266700  ...    1045.84850    1076.44760
# 2013-06-29     928.73820     823.477800  ...     928.72460     945.95740
# 2013-06-30    1011.13700    1067.664000  ...    1011.12950    1021.23145
# 2013-07-01     871.65100    1367.566400  ...     871.64100     883.82860
# 2013-07-02     814.42060    1618.290500  ...     814.41580     820.73870
# 2013-07-03     750.47810    1772.735600  ...     750.47450     754.98267
# 2013-07-04     657.90790    1818.680900  ...     657.90436     662.09940
# 2013-07-05     646.66266    1779.318800  ...     646.66090     648.88025
# 2013-07-06     606.98676    1685.163600  ...     606.98460     609.49070
# 2013-07-07     586.23474    1557.721200  ...     586.23390     587.36554
# 2013-07-08     682.41180    1428.273700  ...     682.41350     680.71470
# 2013-07-09     671.49760    1310.046900  ...     671.49640     672.88965
# 2013-07-10     610.40784    1198.093900  ...     610.40520     613.49316
#
# [40 rows x 220 columns]

# %%
# claculate the objcetive function

# setting the first few rows as NaNa

df_observed[df_observed.index<'2013-06-15'] = None

print(df_observed)
# Out:
#             V_0.5_D_1000  V_0.5_D_10000  ...  V_1.5_D_9000  V_1.5_D_9500
# 2013-06-01           NaN            NaN  ...           NaN           NaN
# 2013-06-02           NaN            NaN  ...           NaN           NaN
# 2013-06-03           NaN            NaN  ...           NaN           NaN
# 2013-06-04           NaN            NaN  ...           NaN           NaN
# 2013-06-05           NaN            NaN  ...           NaN           NaN
# 2013-06-06           NaN            NaN  ...           NaN           NaN
# 2013-06-07           NaN            NaN  ...           NaN           NaN
# 2013-06-08           NaN            NaN  ...           NaN           NaN
# 2013-06-09           NaN            NaN  ...           NaN           NaN
# 2013-06-10           NaN            NaN  ...           NaN           NaN
# 2013-06-11           NaN            NaN  ...           NaN           NaN
# 2013-06-12           NaN            NaN  ...           NaN           NaN
# 2013-06-13           NaN            NaN  ...           NaN           NaN
# 2013-06-14           NaN            NaN  ...           NaN           NaN
# 2013-06-15         434.0          434.0  ...         434.0         434.0
# 2013-06-16         370.0          370.0  ...         370.0         370.0
# 2013-06-17         339.0          339.0  ...         339.0         339.0
# 2013-06-18         360.0          360.0  ...         360.0         360.0
# 2013-06-19         415.0          415.0  ...         415.0         415.0
# 2013-06-20         423.0          423.0  ...         423.0         423.0
# 2013-06-21         526.0          526.0  ...         526.0         526.0
# 2013-06-22         833.0          833.0  ...         833.0         833.0
# 2013-06-23        1420.0         1420.0  ...        1420.0        1420.0
# 2013-06-24        1960.0         1960.0  ...        1960.0        1960.0
# 2013-06-25        2120.0         2120.0  ...        2120.0        2120.0
# 2013-06-26        2210.0         2210.0  ...        2210.0        2210.0
# 2013-06-27        2240.0         2240.0  ...        2240.0        2240.0
# 2013-06-28        2200.0         2200.0  ...        2200.0        2200.0
# 2013-06-29        2010.0         2010.0  ...        2010.0        2010.0
# 2013-06-30        1710.0         1710.0  ...        1710.0        1710.0
# 2013-07-01        1510.0         1510.0  ...        1510.0        1510.0
# 2013-07-02        1120.0         1120.0  ...        1120.0        1120.0
# 2013-07-03        1010.0         1010.0  ...        1010.0        1010.0
# 2013-07-04         748.0          748.0  ...         748.0         748.0
# 2013-07-05         727.0          727.0  ...         727.0         727.0
# 2013-07-06         722.0          722.0  ...         722.0         722.0
# 2013-07-07         724.0          724.0  ...         724.0         724.0
# 2013-07-08         713.0          713.0  ...         713.0         713.0
# 2013-07-09         710.0          710.0  ...         710.0         710.0
# 2013-07-10         693.0          693.0  ...         693.0         693.0
#
# [40 rows x 220 columns]

# %%
df_diff = df - df_observed

df_diff = abs(df_diff)

df_diff = df_diff.sum()

df_diff = df_diff.sort_values()

print(df_diff)
# Out:
# V_0.5_D_1000     12340.84082
# V_0.5_D_10000    15896.41709
# V_0.5_D_1500      9619.80297
# V_0.5_D_2000      6908.57731
# V_0.5_D_2500      4751.20094
#                     ...
# V_1.5_D_7500     13229.55408
# V_1.5_D_8000     12936.29587
# V_1.5_D_8500     12638.75569
# V_1.5_D_9000     12341.09315
# V_1.5_D_9500     12038.40492
# Length: 220, dtype: float64

# %%
import netCDF4 as nc4
dset = nc4.Dataset('/Users/shg096/Downloads//WM.nc')
print(list(dset.variables))
variables = list(dset.variables)

variables = [x for x in variables if x.startswith('Volume_')]

variables = sorted(variables)

for variable in variables:

    # update the case name in the setting file
    with open('./settings/HDMA_CLM5-runoff-lake.control.tmp', "r+") as text_file:
        texts = text_file.read()
        texts = texts.replace("CASENAME", variable)
    with open('./settings/HDMA_CLM5-runoff-lake.control', "w") as text_file:
        text_file.write(texts)
        
    # execute the model
    os.system('./route_runoff.mpi-pio.exe ./settings/HDMA_CLM5-runoff-lake.control')
# Out:
# ['time', 'Volume_03_20_29', 'column_name', 'ID', 'Volume_02_20_29', 'Volume_16_15_27', 'Volume_16_19_30', 'Volume_17_15_27', 'Volume_17_19_30', 'Volume_16_14_29', 'Volume_17_14_29', 'Volume_14_16_30', 'Volume_15_16_30', 'Volume_19_20_27', 'Volume_20_19_29', 'Volume_18_20_27', 'Volume_11_14_26', 'Volume_10_14_26', 'Volume_11_15_28', 'Volume_10_15_28', 'Volume_20_18_27', 'Volume_04_20_26', 'Volume_20_14_30', 'Volume_05_20_26', 'Volume_01_16_28', 'Volume_00_16_28', 'Volume_01_17_26', 'Volume_00_17_26', 
 'Volume_01_16_29', 'Volume_00_16_29', 'Volume_01_17_27', 'Volume_00_17_27', 'Volume_19_15_30', 'Volume_04_18_28', 'Volume_20_20_29', 'Volume_19_19_27', 'Volume_05_18_28', 'Volume_18_15_30', 'Volume_18_19_27', 'Volume_04_19_26', 'Volume_19_18_29', 'Volume_05_19_26', 'Volume_18_18_29', 'Volume_06_17_28', 'Volume_07_17_28', 'Volume_06_16_26', 'Volume_07_16_26', 'Volume_03_19_29', 'Volume_02_19_29', 'Volume_16_20_30', 'Volume_17_20_30', 'Volume_03_18_27', 'Volume_03_14_30', 'Volume_02_18_27', 'Volume_02_14_30', 'Volume_04_16_30', 'Volume_05_16_30', 'Volume_01_14_26', 'Volume_00_14_26', 'Volume_09_20_27', 'Volume_08_20_27', 'Volume_14_20_26', 'Volume_15_20_26', 'Volume_01_15_28', 'Volume_00_15_28', 'Volume_06_15_27', 'Volume_06_19_30', 'Volume_07_15_27', 'Volume_07_19_30', 'Volume_13_20_29', 'Volume_12_20_29', 'Volume_06_14_29', 'Volume_07_14_29', 'Volume_16_17_29', 'Volume_17_17_29', 'Volume_16_16_27', 'Volume_17_16_27', 'Volume_13_19_28', 'Volume_12_19_28', 'Volume_13_18_26', 'Volume_12_18_26', 'Volume_20_17_30', 'Volume_11_16_28', 'Volume_10_16_28', ...
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/yh/b1qy7zb96k980mcb2ps9n6d9t1c6zr/T/ipykernel_18040/1634389794.py in <module>
#      11
#      12     # update the case name in the setting file
# ---> 13     with open('./settings/HDMA_CLM5-runoff-lake.control.tmp', "r+") as text_file:
#      14         texts = text_file.read()
#      15         texts = texts.replace("CASENAME", variable)
#
# FileNotFoundError: [Errno 2] No such file or directory: './settings/HDMA_CLM5-runoff-lake.control.tmp'

# %%
print(len(variables))
# Out:
# 735

# %%
df = pd.read_csv('/Users/shg096/Downloads/final.csv')

df_max = df.max()

# df_max = df_max-2496.6729

df_max = df_max.drop(['Unnamed: 0'])

print(df_max)

vol_total = None
start_date = None
end_date = None

for index in df_max.index:
#     print(index)
    index_list = index.split('_')
    
#     print(index_list)
    
    if vol_total is None:
        vol_total = np.array(float(index_list[1]))
        start_date = np.array(int(index_list[2]))
        end_date = np.array(int(index_list[3]))
    else:
        vol_total = np.append(vol_total,float(index_list[1]))
        start_date = np.append(start_date,int(index_list[2]))
        end_date = np.append(end_date,int(index_list[3]))

print(df_max)

df_final = pd.DataFrame()
df_final['discharge'] = np.array(df_max)
df_final['init'] = vol_total
df_final['start'] = start_date
df_final['end'] = end_date

print(df_final)
# Out:
# Volume_00_14_26    2496.6729
# Volume_00_14_27    2496.6729
# Volume_00_14_28    2496.6729
# Volume_00_14_29    2496.6729
# Volume_00_14_30    2496.6729
#                      ...
# Volume_20_20_26    1606.9940
# Volume_20_20_27    1436.4912
# Volume_20_20_28    1495.5641
# Volume_20_20_29    1613.1660
# Volume_20_20_30    1696.7494
# Length: 735, dtype: float64
# Volume_00_14_26    2496.6729
# Volume_00_14_27    2496.6729
# Volume_00_14_28    2496.6729
# Volume_00_14_29    2496.6729
# Volume_00_14_30    2496.6729
#                      ...
# Volume_20_20_26    1606.9940
# Volume_20_20_27    1436.4912
# Volume_20_20_28    1495.5641
# Volume_20_20_29    1613.1660
# Volume_20_20_30    1696.7494
# Length: 735, dtype: float64
#      discharge  init  start  end
# 0    2496.6729   0.0     14   26
# 1    2496.6729   0.0     14   27
# 2    2496.6729   0.0     14   28
# 3    2496.6729   0.0     14   29
# 4    2496.6729   0.0     14   30
# ..         ...   ...    ...  ...
# 730  1606.9940  20.0     20   26
# 731  1436.4912  20.0     20   27
# 732  1495.5641  20.0     20   28
# 733  1613.1660  20.0     20   29
# 734  1696.7494  20.0     20   30
#
# [735 rows x 4 columns]

# %%
from matplotlib.ticker import MaxNLocator
#...



fig, axs = plt.subplots(2, 2, figsize=(20, 20)) # 


depth = np.array([5,10,15,20])
m = 0

for i in np.arange(2):
    for j in np.arange(2):

        #
        df_final_slice = df_final[df_final['init']==depth[m]]
        A = axs[i,j].scatter(df_final_slice.start, df_final_slice.end,
                             c=df_final_slice.discharge,
                             vmin = df_final['discharge'].min(),
                             vmax = df_final['discharge'].max(),
                             s=500)
        axs[i,j].grid()
        axs[i,j].xaxis.set_major_locator(MaxNLocator(integer=True))
        axs[i,j].yaxis.set_major_locator(MaxNLocator(integer=True))
        axs[i,j].set_title('Initial Elevation '+ str(depth[m]/10) + ' [m] \n Below the Historical Elevation')
        if j == 0 :
            axs[i,j].set_ylabel('Day of May Reaction Ended')
        if i == 1 :
            axs[i,j].set_xlabel('Day of May Reaction Started')
        
        m = m + 1

# A.colorbar()

pos2 = axs[1, 1].get_position()

cb_ax = fig.add_axes([pos2.x1+0.02, pos2.y0, 0.02, pos2.y1-pos2.y0])
cbar  = fig.colorbar(A, cax=cb_ax)

cbar.ax.set_title('Peak Discharge \n [cms]')

plt.savefig('../fig/Max_discharge_Saskatoon_2D.png',dpi=200)

# %%
df = pd.read_csv('/Users/shg096/Downloads/final.csv')

df_max = df.max()

df_max = df_max-2496.6729

df_max = df_max.drop(['Unnamed: 0'])

print(df_max)

vol_total = None
start_date = None
end_date = None

for index in df_max.index:
#     print(index)
    index_list = index.split('_')
    
#     print(index_list)
    
    if vol_total is None:
        vol_total = np.array(float(index_list[1]))
        start_date = np.array(int(index_list[2]))
        end_date = np.array(int(index_list[3]))
    else:
        vol_total = np.append(vol_total,float(index_list[1]))
        start_date = np.append(start_date,int(index_list[2]))
        end_date = np.append(end_date,int(index_list[3]))

print(df_max)

df_final = pd.DataFrame()
df_final['discharge'] = np.array(df_max)
df_final['init'] = vol_total
df_final['start'] = start_date
df_final['end'] = end_date

print(df_final)
# Out:
# Volume_00_14_26       0.0000
# Volume_00_14_27       0.0000
# Volume_00_14_28       0.0000
# Volume_00_14_29       0.0000
# Volume_00_14_30       0.0000
#                      ...
# Volume_20_20_26    -889.6789
# Volume_20_20_27   -1060.1817
# Volume_20_20_28   -1001.1088
# Volume_20_20_29    -883.5069
# Volume_20_20_30    -799.9235
# Length: 735, dtype: float64
# Volume_00_14_26       0.0000
# Volume_00_14_27       0.0000
# Volume_00_14_28       0.0000
# Volume_00_14_29       0.0000
# Volume_00_14_30       0.0000
#                      ...
# Volume_20_20_26    -889.6789
# Volume_20_20_27   -1060.1817
# Volume_20_20_28   -1001.1088
# Volume_20_20_29    -883.5069
# Volume_20_20_30    -799.9235
# Length: 735, dtype: float64
#      discharge  init  start  end
# 0       0.0000   0.0     14   26
# 1       0.0000   0.0     14   27
# 2       0.0000   0.0     14   28
# 3       0.0000   0.0     14   29
# 4       0.0000   0.0     14   30
# ..         ...   ...    ...  ...
# 730  -889.6789  20.0     20   26
# 731 -1060.1817  20.0     20   27
# 732 -1001.1088  20.0     20   28
# 733  -883.5069  20.0     20   29
# 734  -799.9235  20.0     20   30
#
# [735 rows x 4 columns]

# %%
from matplotlib.ticker import MaxNLocator
#...



fig, axs = plt.subplots(2, 2, figsize=(20, 20)) # 


depth = np.array([5,10,15,20])
m = 0

for i in np.arange(2):
    for j in np.arange(2):

        #
        df_final_slice = df_final[df_final['init']==depth[m]]
        A = axs[i,j].scatter(df_final_slice.start, df_final_slice.end,
                             c=df_final_slice.discharge,
                             vmin = df_final['discharge'].min(),
                             vmax = df_final['discharge'].max(),
                             s=500)
        axs[i,j].grid()
        axs[i,j].xaxis.set_major_locator(MaxNLocator(integer=True))
        axs[i,j].yaxis.set_major_locator(MaxNLocator(integer=True))
        axs[i,j].set_title('Initial Elevation '+ str(depth[m]/10) + ' [m] \n Below the Historical Elevation')
        if j == 0 :
            axs[i,j].set_ylabel('Day of May Reaction Ended')
        if i == 1 :
            axs[i,j].set_xlabel('Day of May Reaction Started')
        
        m = m + 1

# A.colorbar()

pos2 = axs[1, 1].get_position()

cb_ax = fig.add_axes([pos2.x1+0.02, pos2.y0, 0.02, pos2.y1-pos2.y0])
cbar  = fig.colorbar(A, cax=cb_ax)

cbar.ax.set_title('Peak Discharge \n [cms]')
# Out:
# Text(0.5, 1.0, 'Peak Discharge \n [cms]')

# %%
df_1  = pd.read_csv('../data/target_storage/Scenario_00_14_28.csv')

df_2  = pd.read_csv('../data/target_storage/Scenario_05_17_27.csv')

df_3  = pd.read_csv('../data/target_storage/Scenario_10_14_30.csv')

df_4  = pd.read_csv('../data/target_storage/Scenario_15_15_28.csv')

df_5  = pd.read_csv('../data/target_storage/Scenario_20_20_26.csv')

df_1['Datetime'] = pd.to_datetime(df_1['Unnamed: 0'])
df_1 = df_1.set_index('Datetime')

df_2['Datetime'] = pd.to_datetime(df_2['Unnamed: 0'])
df_2 = df_2.set_index('Datetime')

df_3['Datetime'] = pd.to_datetime(df_3['Unnamed: 0'])
df_3 = df_3.set_index('Datetime')

df_4['Datetime'] = pd.to_datetime(df_4['Unnamed: 0'])
df_4 = df_4.set_index('Datetime')

df_5['Datetime'] = pd.to_datetime(df_5['Unnamed: 0'])
df_5 = df_5.set_index('Datetime')



df_1['R13'].plot(figsize=(15,7),lw=3)
df_2['R13'].plot(figsize=(15,7),lw=3)
df_3['R13'].plot(figsize=(15,7),lw=3)
df_4['R13'].plot(figsize=(15,7),lw=3)
df_5['R13'].plot(figsize=(15,7),lw=3)


plt.grid(axis='y')
plt.xlabel('Date [-]')
plt.ylabel('Target Volume [m3]')

plt.savefig('../fig/sample_scenarios.png',dpi=200)

# %%
import pandas as pd
import matplotlib.pyplot as plt
#import datetime #import date
import matplotlib.pyplot  as plt
import matplotlib
from ipynb.fs.full.Untitled2 import save_netcdf
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 30}
matplotlib.rc('font', **font)



df = pd.read_csv('/Users/shg096/Downloads/final_ensemble.csv')
print(df)


df = df.drop(columns=['Unnamed: 0'])
index = pd.date_range(start='2013-06-01', end='2013-07-10')
df = df.set_index(index)

# load opservation
observation = pd.read_csv('../data/observation_05HG001.csv')
observation['time'] = pd.to_datetime(observation['time'])
observation = observation.set_index('time')


# plotting
fig, ax = plt.subplots(figsize=(15,10))



df.plot(ax=ax,color = 'b',linewidth=3.0)
observation.plot(ax=ax,style='--r',linewidth=5.0)
plt.grid(which='both')
plt.gca().get_legend().remove()
plt.ylabel('Streamflows at \n Saskatoon [cms]')
# plt.xlabel('Date')
plt.title('Ensemble of Streamflows at Saskatoon')
plt.tight_layout()
plt.savefig('../fig/Saskatoon_Streamflow_Ensemble.png', dpi=400)
# Out:
#     Unnamed: 0  Volume_00_0_0  Volume_00_0_1  Volume_00_0_2  Volume_00_0_3  \
# 0            0      24.561253      24.561253      24.561253      24.561253
# 1            1      36.910126      36.910126      36.910126      36.910126
# 2            2      33.395820      33.395820      33.395820      33.395820
# 3            3      85.854600      85.854600      85.854600      85.854600
# 4            4     207.661970     207.661970     207.661970     207.661970
# 5            5     333.253080     333.253080     333.253080     333.253080
# 6            6     421.890080     421.890080     421.890080     421.890080
# 7            7     441.637330     441.637330     441.637330     441.637330
# 8            8     437.174000     437.174000     437.174000     437.174000
# 9            9     450.361940     450.361940     450.361940     450.361940
# 10          10     480.758730     480.758730     480.758730     480.758730
# 11          11     507.508670     507.508670     507.508670     507.508670
# 12          12     500.355960     500.355960     500.355960     500.355960
# 13          13     450.418980     450.418980     450.418980     450.418980
# 14          14     373.876250     373.876250     373.876250     373.876250
# 15          15     357.393400     357.393400     357.393400     357.393400
# 16          16     379.964420     379.964420     379.964420     379.964420
# 17          17     403.395400     403.395400     403.395400     403.395400
# 18          18     445.771550     445.771550     445.771550     445.771550
# 19          19     457.244660     457.244660     457.244660     457.244660
# 20          20     485.305940     485.305940     485.305940     485.305940
# 21          21     683.939000     683.939000     683.939000     683.939000
# 22          22    1183.887100    1183.887100    1183.887100    1183.887100
# 23          23    1874.749600    1874.749600    1874.749600    1874.749600
# 24          24    2297.161400    2323.318800    2336.645800    2345.314700
# 25          25    2300.464600    2313.616200    2377.622800    2419.258300
# 26          26    2126.960200    2112.923000    2134.583700    2229.672900
# 27          27    1995.810200    1980.493800    1941.937700    1957.582200
# 28          28    1906.810400    1899.954700    1862.906700    1795.340500
# 29          29    1832.569600    1830.364700    1814.222200    1756.293200
# 11     463.345550     463.345550     463.345550     463.345550     463.345550
# 12     500.959600     500.959600     500.959600     500.959600     500.959600
# 13     545.215500     545.215500     545.215500     545.215500     545.215500
# 14     609.239440     609.239440     609.239440     609.239440     609.239440
# 15     635.382450     635.382450     635.382450     635.382450     635.382450
# 16     661.767460     661.767460     661.767460     661.767460     661.767460
# 17     809.420300     809.420300     809.420300     809.420300     809.420300
# 18    1119.858600    1119.858600    1119.858600    1119.858600    1119.858600
# 19    1360.776700    1360.776700    1360.776700    1360.776700    1360.776700
# 20    1433.787200    1433.787200    1433.787200    1433.787200    1433.787200
# 21    1452.449100    1452.449100    1452.449100    1452.449100    1452.449100
# 22    1568.110200    1568.110200    1568.110200    1568.110200    1568.110200
# 23    1945.021200    1945.021200    1945.021200    1945.021200    1945.021200
# 24    1685.491800    1685.491800    1685.491800    1685.491800    1685.491800
# 25     902.754330     902.754330     902.754330     902.754330     902.754330
# 26     334.016720     334.016720     334.016720     334.016720     334.016720
# 27     101.809660     101.809660     101.809660     101.809660     101.809660
# 28      28.759714      28.759714      28.759714      28.759714      28.759714
# 29       7.441748       7.441748       7.441748       7.441748     116.682800
# 30     226.751040     226.751040     226.751040     226.751040     281.675100
# 31     628.949650     628.949650     628.949650     628.949650     570.326970
# 32     886.455300     886.455300     886.455300     886.455300     822.490200
# 33     906.097800     906.097800     906.097800     906.097800     877.466740
# 34     840.183350     840.183350     840.183350     840.183350     830.975900
# 35     770.125400     770.125400     770.125400     770.125400     767.382800
# 36     706.991900     706.991900     706.991900     706.991900     706.225100
# 37     697.964660     697.964660     697.964660     697.964660     697.781430
# 38     706.451540     706.451540     706.451540     706.451540     706.414250
# 39     692.473270     692.473270     692.473270     692.473270     692.466060
#
#     Volume_20_4_7
# 0       24.561253
# 1       36.910126
# 2       62.834920
# 3      127.437380
# 4      231.499800
# 5      346.371800
# 6      443.693400
# 7      511.431000
# 8      536.550540
# 9      516.085900
# 10     464.147160
# 11     463.345550
# 12     500.959600
# 13     545.215500
# 14     609.239440
# 15     635.382450
# 16     661.767460
# 17     809.420300
# 18    1119.858600
# 19    1360.776700
# 20    1433.787200
# 21    1452.449100
# 22    1568.110200
# 23    1945.021200
# 24    1685.491800
# 25     902.754330
# 26     334.016720
# 27     101.809660
# 28      82.246025
# 29     315.444270
# 30     522.787500
# 31     538.987900
# 32     609.414500
# 33     720.523250
# 34     767.078740
# 35     747.234130
# 36     700.324400
# 37     696.187560
# 38     706.044430
# 39     692.391500
#
# [40 rows x 201 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
#import datetime #import date
import matplotlib.pyplot  as plt
import matplotlib
from ipynb.fs.full.Untitled2 import save_netcdf
font = {'family' : 'Times New Roman',
        'weight' : 'bold',
        'size'   : 30}
matplotlib.rc('font', **font)



df = pd.read_csv('../data/Storage_ensemble_Scenarios.csv')
print(df)

# load opservation
df['Date'] = pd.to_datetime(df['Date'])
df = df.set_index('Date')


# plotting
fig, ax = plt.subplots(figsize=(15,10))

df.plot(ax=ax,color = 'b',linewidth=3.0)
df['Scenario_00_0_0'].plot(ax=ax,style='--r',linewidth=5.0)
plt.grid(which='both')
plt.gca().get_legend().remove()
plt.ylabel('Storage of \n Lake Diefenbaker [m3]')
# plt.xlabel('Date')
plt.title('Ensemble of Lake Diefenbaker Operation \n During Flood of June 2013')
plt.tight_layout()
plt.savefig('../fig/Lake_Diefenbaker_scenarios.png', dpi=400)
# Out:
#           Date  Scenario_00_0_0  Scenario_05_0_0  Scenario_10_0_0  \
# 0   2013-06-01     7.867203e+09     7.678404e+09     7.503166e+09
# 1   2013-06-02     7.902320e+09     7.713520e+09     7.535473e+09
# 2   2013-06-03     7.934038e+09     7.745239e+09     7.564655e+09
# 3   2013-06-04     7.970288e+09     7.781488e+09     7.598004e+09
# 4   2013-06-05     8.002384e+09     7.813584e+09     7.627533e+09
# 5   2013-06-06     8.034480e+09     7.845680e+09     7.657062e+09
# 6   2013-06-07     8.063933e+09     7.875133e+09     7.686333e+09
# 7   2013-06-08     8.104336e+09     7.915536e+09     7.726736e+09
# 8   2013-06-09     8.139453e+09     7.950653e+09     7.761853e+09
# 9   2013-06-10     8.172304e+09     7.983504e+09     7.794704e+09
# 10  2013-06-11     8.199869e+09     8.011069e+09     7.822269e+09
# 11  2013-06-12     8.226300e+09     8.037501e+09     7.848701e+09
# 12  2013-06-13     8.258396e+09     8.069597e+09     7.880797e+09
# 13  2013-06-14     8.297289e+09     8.108489e+09     7.919690e+09
# 14  2013-06-15     8.341846e+09     8.153046e+09     7.964246e+09
# 15  2013-06-16     8.366768e+09     8.177968e+09     7.989168e+09
# 16  2013-06-17     8.393199e+09     8.204400e+09     8.015600e+09
# 17  2013-06-18     8.410569e+09     8.221769e+09     8.032970e+09
# 18  2013-06-19     8.415478e+09     8.226678e+09     8.037878e+09
# 19  2013-06-20     8.429071e+09     8.240272e+09     8.051472e+09
# 20  2013-06-21     8.423030e+09     8.234230e+09     8.045430e+09
# 21  2013-06-22     8.374320e+09     8.185520e+09     7.996720e+09
# 22  2013-06-23     8.273123e+09     8.084323e+09     7.895523e+09
# 23  2013-06-24     8.190051e+09     8.001251e+09     7.812451e+09
# 24  2013-06-25     8.247068e+09     8.247068e+09     8.247068e+09
# 25  2013-06-26     8.396220e+09     8.396220e+09     8.396220e+09
# 26  2013-06-27     8.563149e+09     8.563149e+09     8.563149e+09
# 27  2013-06-28     8.692753e+09     8.692753e+09     8.692753e+09
# 28  2013-06-29     8.785327e+09     8.785327e+09     8.785327e+09
# 29  2013-06-30     8.833297e+09     8.833297e+09     8.833297e+09
# 30  2013-07-01     8.883792e+09     8.883792e+09     8.883792e+09
# 31  2013-07-02     8.916613e+09     8.916613e+09     8.916613e+09
# 32  2013-07-03     8.949856e+09     8.949856e+09     8.949856e+09
# 33  2013-07-04     8.984781e+09     8.984781e+09     8.984781e+09
# 34  2013-07-05     9.010450e+09     9.010450e+09     9.010450e+09
# 35  2013-07-06     9.038643e+09     9.038643e+09     9.038643e+09
# 36  2013-07-07     9.064732e+09     9.064732e+09     9.064732e+09
# 37  2013-07-08     9.076093e+09     9.076093e+09     9.076093e+09
# 38  2013-07-09     9.092504e+09     9.092504e+09     9.092504e+09
